# %%
# IMPORTS
import pandas as pd
import numpy as np
import spacy
from transformers import RobertaTokenizerFast, RobertaForSequenceClassification, pipeline

# %% [markdown]
# ### **Process Corpus Text**

# %%
# IMPORT NOVEL TEXT
with open("MV_Abrv_Full.txt", "r", encoding="utf-8") as file:
    content = file.readlines()

# %%
# SEPARATE SENTENCES
content = [c.rstrip()+" " for c in content]
content = "".join(content)
content = content.split(". ")
content = [c+"." for c in content]

# %% [markdown]
# ### **Initialize SpaCy and BERT Models**

# %% [markdown]
# The SpaCy model is used in this notebook for Named Entity Recognition (NER)

# %%
# INITIATE English SpaCy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The BERT model is used for Emotion Detection (ED)
# * based on the entire sentence sentiment (later referred as "Sentence Emotion")
# * not on a deeper understanding of the meaning
# * 2 models are explored: AG and BS (abbreviated by their authors' names)

# %%
# Emotion Detector
tokenizer = RobertaTokenizerFast.from_pretrained("arpanghoshal/EmoRoBERTa")
model = RobertaForSequenceClassification.from_pretrained("arpanghoshal/EmoRoBERTa", from_tf=True)
emotion = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# Out:
# All TF 2.0 model weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
emotion2 = pipeline("text-classification", model='bhadresh-savani/distilbert-base-uncased-emotion', top_k=None)

# %% [markdown]
# ### **Analysis**

# %% [markdown]
# #### **#1:** Identification of Characters and Sentence Emotions

# %% [markdown]
# Each sentence is a discrete timestep, where:
# * one character is identified at max, if any (no Entity Disambiguation)
# * an overall sentence emotion

# %%
# Initializing Dataframe
df = pd.DataFrame(columns=["Sentence", "Entities", "Persons", "SynDep", "Emotion_AG", "Emotion_BS"])
df["Sentence"] = content

# %%
# Populating Dataframe
for i in df.index:

    sentence_nlp = nlp(df["Sentence"][i])
    entities = sentence_nlp.ents
    entities_dict = {str(t): t.label_ for t in entities}
    indices_entities = [e.start for e in entities if e.label_=="PERSON"]

    df["Entities"][i] = entities_dict
    df["Persons"][i] = [e.lemma_ for e in entities if e.label_=="PERSON"] # Only keep Named Enities who are Persons
    df["SynDep"][i] = [sentence_nlp[ind+1].dep_ \
                       if sentence_nlp[ind].dep_=="compound" \
                        else sentence_nlp[ind].dep_ \
                            for ind in indices_entities ]  
    df["Emotion_AG"][i] = emotion(df["Sentence"][i])[0]['label'] # ED model 1
    df["Emotion_BS"][i] = emotion2(df["Sentence"][i])[0][0]['label'] # ED model 2

# %%
df.head(50)
# Out:
#                                              Sentence
# 0                  Shylock, the Jew, lived at Venice.  \
# 1   He was a usurer who had amassed an immense for...
# 2   Shylock, being a hard-hearted man, exacted the...
# 3   Whenever Antonio met Shylock on the Rialto, (o...
# 4    Antonio was the kindest man that lived, the b...
# 5   He was greatly beloved by all his fellow-citiz...
# 6   Whenever Bassanio wanted money Antonio assiste...
# 7    One day Bassanio came to Antonio and told him...
# 8    Antonio had no money by him at that time to l...
# 9   some ships come home laden with merchandise, h...
# 10   Antonio and Bassanio went together to Shylock...
# 11   On this, Shylock thought within himself: “If ...
# 12  He hates our Jewish nation; he lends out money...
# 13  Cursed be my tribe if I forgive him!”  Antonio...
# 14  Well, then, it now appears you need my help, a...
# 15  If you will lend me this money, lend it not to...
# 16     I will forget the shames you have put upon me.
# 17  I will supply your wants and take no interest ...
# 18                           “Content,” said Antonio.
# 19  “I will sign to this bond, and say there is mu...
# 20   Shylock, hearing this debate, exclaimed: “O F...
# 21  I pray you tell me this, Bassanio: if he shoul...
# 22  I say, to buy his favor I offer this friendshi...
# 23   The rich heiress that Bassanio wished to marr...
# 24  Her name was Portia, and in the graces of her ...
# 25   Bassanio being so kindly supplied with money ...
# 26   Bassanio proving successful in his suit, Port...
# 27   Bassanio confessed to Portia that he had no f...
# 28  But yesterday, Bassanio, I was the lady of thi...
# 29   Bassanio was so overpowered with gratitude an...
# 30   Gratiano and Nerissa, Portia’s waiting-maid, ...
# 31   “With all my heart, Gratiano,” said Bassanio,...
# 32             Portia asked Nerissa if this was true.
# 33  Nerissa replied:  “Madam, it is so, if you app...
# 34  When Bassanio read Antonio’s letter, Portia fe...
# 35  If your love for me do not persuade you to com...
# 36   The day of payment being past, the cruel Jew ...
# 37  A day was appointed to try this shocking cause...
# 38   When Portia parted with her husband she spoke...
# 39  And notwithstanding when she wished to honor h...
# 40   Portia had a relation who was a counselor in ...
# 41  When the messenger returned he brought letters...
# 42   Portia dressed herself and her maid Nerissa i...
# 43  The cause was just going to be heard before th...
# 44  This the Duke granted, much wondering at the y...
# 45                And now began this important trial.
# 46  Portia looked around her and she saw the merci...
# 47  He was standing beside Antonio, in an agony of...
# 48   The importance of the arduous task Portia had...
# 49  And first of all she addressed herself to Shyl...
#
#                                              Entities
# 0   {'Shylock': 'PERSON', 'Jew': 'NORP', 'Venice':...  \
# 1                               {'Christian': 'NORP'}
# 2   {'Shylock': 'PERSON', 'Antonio': 'PERSON', 'Ve...
# 3   {'Antonio': 'PERSON', 'Shylock': 'PERSON', 'Ri...
# 4   {'Antonio': 'PERSON', 'Roman': 'NORP', 'Italy'...
# 5          {'Bassanio': 'PERSON', 'Venetian': 'NORP'}
# 6   {'Bassanio': 'PERSON', 'Antonio': 'PERSON', 'o...
# 7   {'One day': 'DATE', 'Bassanio': 'GPE', 'Antoni...
# 8                               {'Antonio': 'PERSON'}
# 9                               {'Shylock': 'PERSON'}
# 10  {'Antonio': 'PERSON', 'Bassanio': 'GPE', 'Shyl...
# 11                              {'Shylock': 'PERSON'}
# 12                                 {'Jewish': 'NORP'}
# 13  {'Antonio': 'PERSON', 'Shylock': 'PERSON', 'Je...
# 14  {'three thousand ducats': 'QUANTITY', 'Wednesd...
# 15                              {'Shylock': 'PERSON'}
# 16                                                 {}
# 17  {'Antonio': 'PERSON', 'Shylock': 'PERSON', 'th...
# 18                              {'Antonio': 'PERSON'}
# 19  {'Jew': 'NORP', 'Bassanio': 'PERSON', 'Antonio...
# 20  {'Shylock': 'PERSON', 'Abraham': 'PERSON', 'Ch...
# 21          {'Bassanio': 'PERSON', 'his day': 'DATE'}
# 22  {'Bassanio': 'GPE', 'Jew': 'PERSON', 'Antonio'...
# 23  {'Bassanio': 'PERSON', 'Venice': 'GPE', 'Belmo...
# 24  {'Portia': 'PERSON', 'Cato': 'ORG', 'Brutus': ...
# 25  {'Antonio': 'PERSON', 'Belmont': 'GPE', 'Grati...
# 26                               {'Portia': 'PERSON'}
# 27  {'Portia': 'PERSON', 'a thousand': 'CARDINAL',...
# 28           {'yesterday': 'DATE', 'Bassanio': 'GPE'}
# 29                               {'Portia': 'PERSON'}
# 30  {'Portia': 'PERSON', 'Bassanio': 'PERSON', 'Gr...
# 31  {'Gratiano': 'ORG', 'Bassanio': 'GPE', 'Neriss...
# 32          {'Portia': 'PERSON', 'Nerissa': 'PERSON'}
# 33  {'Madam': 'WORK_OF_ART', 'Portia': 'PERSON', '...
# 34  {'Bassanio': 'PERSON', 'Antonio': 'PERSON', 'P...
# 35  {'Portia': 'PERSON', 'twenty': 'CARDINAL', 'Ba...
# 36  {'The day': 'DATE', 'Jew': 'PERSON', 'Bassanio...
# 37  {'the Duke of Venice': 'GPE', 'Bassanio': 'PER...
# 38  {'Portia': 'PERSON', 'Antonio': 'PERSON', 'Bas...
# 39                {'Venice': 'GPE', 'Antonio': 'GPE'}
# 40                               {'Portia': 'PERSON'}
# 41                                                 {}
# 42  {'Portia': 'PERSON', 'Venice': 'GPE', 'the ver...
# 43  {'Venice': 'GPE', 'the Senate House': 'ORG', '...
# 44                                                 {}
# 45                                                 {}
# 46  {'Portia': 'PERSON', 'Jew': 'NORP', 'Bassanio'...
# 47                              {'Antonio': 'PERSON'}
# 48                               {'Portia': 'PERSON'}
# 49  {'first': 'ORDINAL', 'Shylock': 'PERSON', 'Ven...
#
#                                               Persons
# 0                                           [Shylock]  \
# 1                                                  []
# 2       [Shylock, Antonio, Shylock, Antonio, Antonio]
# 3                                  [Antonio, Shylock]
# 4                                           [Antonio]
# 5                                          [Bassanio]
# 6                                 [Bassanio, Antonio]
# 7                                  [Antonio, Antonio]
# 8                                           [Antonio]
# 9                                           [Shylock]
# 10                        [Antonio, Shylock, Antonio]
# 11                                          [Shylock]
# 12                                                 []
# 13                 [Antonio, Shylock, Signor Antonio]
# 14                                          [Antonio]
# 15                                          [Shylock]
# 16                                                 []
# 17      [Antonio, Shylock, Antonio, Antonio, Shylock]
# 18                                          [Antonio]
# 19                       [Bassanio, Antonio, Antonio]
# 20                                 [Shylock, Abraham]
# 21                                         [Bassanio]
# 22                                     [Antonio, Jew]
# 23                                         [Bassanio]
# 24                           [Portia, Portia, Brutus]
# 25                                          [Antonio]
# 26                                           [Portia]
# 27                                   [Portia, Portia]
# 28                                         [Bassanio]
# 29                                           [Portia]
# 30                         [Portia, Portia, Bassanio]
# 31                                [Bassanio, Nerissa]
# 32                                  [Portia, Nerissa]
# 33                                  [Portia, Antonio]
# 34  [Bassanio, Antonio, Portia, Portia, Portia, An...
# 35      [Portia, Portia, Bassanio, Bassanio, Antonio]
# 36                           [Jew, Bassanio, Antonio]
# 37                                         [Bassanio]
# 38                                  [Portia, Antonio]
# 39                                                 []
# 40                                           [Portia]
# 41                                                 []
# 42                                           [Portia]
# 43               [Portia, Antonio, Balthasar, Portia]
# 44                                                 []
# 45                                                 []
# 46                                 [Portia, Bassanio]
# 47                                          [Antonio]
# 48                                           [Portia]
# 49                        [Shylock, Shylock, Shylock]
#
#                                                SynDep   Emotion_AG Emotion_BS
# 0                                             [nsubj]      neutral       fear
# 1                                                  []      neutral        joy
# 2                   [nsubj, pobj, nsubj, dobj, appos]        anger      anger
# 3                                       [nsubj, dobj]      neutral      anger
# 4                                             [nsubj]   admiration      anger
# 5                                              [attr]         love        joy
# 6                                      [nsubj, nsubj]      neutral        joy
# 7                                        [pobj, dobj]      neutral    sadness
# 8                                             [nsubj]      neutral      anger
# 9                                              [pobj]      neutral        joy
# 10                               [nsubj, pobj, nsubj]      neutral      anger
# 11                                            [nsubj]      neutral       fear
# 12                                                 []      neutral      anger
# 13                             [nsubj, npadvmod, dep]      neutral      anger
# 14                                            [nsubj]      neutral      anger
# 15                                            [nsubj]      neutral       fear
# 16                                                 []  realization    sadness
# 17                   [dobj, conj, poss, nsubj, nsubj]      neutral   surprise
# 18                                            [nsubj]      neutral        joy
# 19                              [nsubj, nsubj, nsubj]      neutral      anger
# 20                                  [nsubj, npadvmod]      neutral       fear
# 21                                              [dep]    curiosity        joy
# 22                                     [nsubj, nsubj]      neutral   surprise
# 23                                            [nsubj]       desire        joy
# 24                                 [attr, pobj, pobj]      neutral      anger
# 25                                            [appos]      neutral        joy
# 26                                            [appos]      neutral        joy
# 27                                      [pobj, nsubj]      neutral        joy
# 28                                         [npadvmod]      neutral        joy
# 29                                            [nsubj]    gratitude        joy
# 30                                [poss, nsubj, dobj]      neutral        joy
# 31                                     [nsubj, appos]      neutral       love
# 32                                      [nsubj, dobj]      neutral        joy
# 33                                      [nsubj, pobj]      neutral       fear
# 34  [nsubj, poss, nsubj, nsubj, dobj, pobj, nsubj,...       desire       love
# 35                 [nsubj, nsubj, nsubj, nsubj, dobj]         love      anger
# 36                               [nsubj, nsubj, poss]      neutral      anger
# 37                                            [nsubj]         fear      anger
# 38                                      [nsubj, pobj]         fear       fear
# 39                                                 []      neutral        joy
# 40                                            [nsubj]      neutral       love
# 41                                                 []      neutral        joy
# 42                                            [nsubj]      neutral      anger
# 43                     [nsubj, pobj, nsubjpass, oprd]      neutral        joy
# 44                                                 []     surprise        joy
# 45                                                 []      neutral        joy
# 46                                      [nsubj, dobj]      neutral      anger
# 47                                             [pobj]      neutral       fear
# 48                                            [nsubj]   admiration        joy
# 49                                 [pobj, conj, dobj]      neutral       love

# %%
df["Person1"] = [p[0] if p else "" for p in df["Persons"]] # Assign emotion to 1st Named Entity identified (simplification by this baseline notebook model)

# %% [markdown]
# The lack of a "neutral" emotion label in the BS model results in an overfitting of non-neutral emotions when none exist

# %% [markdown]
# #### **2:** Emotional Timeline of Characters

# %%
dfp = df.reset_index().pivot(index=["index"], columns=["Person1"], values="Emotion_AG")
dfp1 = df.reset_index().pivot(index=["index"], columns=["Person1"], values="Emotion_BS")

# %%
#dfp = dfp.fillna(method="ffill", axis=0) # Forward fill the detected emotion of a character
dfp = dfp.fillna("") # Replace NaN with ""
dfp = dfp[dfp.columns.drop("")] # Drop non-character sentences
dfp.index.names = ["TimeStep"]

# %%
#dfp1 = dfp1.fillna(method="ffill", axis=0) # Forward fill the detected emotion of a character
dfp1 = dfp1.fillna("") # Replace NaN with ""
dfp1 = dfp1[dfp1.columns.drop("")] # Drop non-character sentences
dfp1.index.names = ["TimeStep"]

# %%
dfp["Sentence"] = df["Sentence"]
dfp.head()
# Out:
# Person1      Antonio Bassanio Jew Portia  Shylock again Shylock that--
# TimeStep
# 0                                         neutral                       \
# 1
# 2                                           anger
# 3            neutral
# 4         admiration
#
# Person1                                            Sentence
# TimeStep
# 0                        Shylock, the Jew, lived at Venice.
# 1         He was a usurer who had amassed an immense for...
# 2         Shylock, being a hard-hearted man, exacted the...
# 3         Whenever Antonio met Shylock on the Rialto, (o...
# 4          Antonio was the kindest man that lived, the b...

# %%
dfp1["Sentence"] = df["Sentence"]
dfp1.head()
# Out:
# Person1  Antonio Bassanio Jew Portia Shylock again Shylock that--
# TimeStep
# 0                                       fear                       \
# 1
# 2                                      anger
# 3          anger
# 4          anger
#
# Person1                                            Sentence
# TimeStep
# 0                        Shylock, the Jew, lived at Venice.
# 1         He was a usurer who had amassed an immense for...
# 2         Shylock, being a hard-hearted man, exacted the...
# 3         Whenever Antonio met Shylock on the Rialto, (o...
# 4          Antonio was the kindest man that lived, the b...

# %%
dfp.to_csv("MV_emotional_timeline_AG.csv")
dfp1.to_csv("MV_emotional_timeline_BS.csv")

# %% [markdown]
# Potential Improvements:
# * Add logic to extract emotion form sentences without a proper noun name
# * Add logic to apply emotion to multiple persons if mentioned in same sentence
# * Add logic to extract who has which emotion (subject/object)

# %% [markdown]
# ### **Observations on Shortcomings of Initial Model**

# %% [markdown]
# #### **#1:** Long Sentences
# * are more likely to containt Multiple NERs
# * with Multiple Emotions
# * not captured by this initial model

# %%
dfp[dfp.index==2]
# Out:
# Person1  Antonio Bassanio Jew Portia Shylock again Shylock that--
# TimeStep
# 2                                      anger                       \
#
# Person1                                            Sentence
# TimeStep
# 2         Shylock, being a hard-hearted man, exacted the...

# %%
print(dfp["Sentence"][2])
# Out:
# Shylock, being a hard-hearted man, exacted the payment of the money he lent with such severity that he was much disliked by all good men, and particularly by Antonio, a young merchant of Venice; and Shylock as much hated Antonio, because he used to lend money to people in distress, and would never take any interest for the money he lent; therefore there was great enmity between this covetous Jew and the generous merchant Antonio.

# %% [markdown]
# * Long sentence with many idea, perhaps **good to split at the semi-colon**
# * Shylock has **hatred, not anger** (limitation of chosen model)
# * Emotion **assigned only to one Person while multiple persons have emotions** (e.g., Antonio also "dislikes" (hatred) Shylock
# * "all good men" also exhibit a dislike/hatred emotion, unidentified as they are not a Named Entity

# %% [markdown]
# #### **#2:** Emotion Assigned to Wrong Entity/Person

# %%
dfp[dfp.index==4]
# Out:
# Person1      Antonio Bassanio Jew Portia Shylock again Shylock that--
# TimeStep
# 4         admiration                                                   \
#
# Person1                                            Sentence
# TimeStep
# 4          Antonio was the kindest man that lived, the b...

# %%
print(dfp["Sentence"][4])
# Out:
#  Antonio was the kindest man that lived, the best conditioned, and had the most unwearied spirit in doing courtesies; indeed, he was one in whom the ancient Roman honor more appeared than in any that drew breath in Italy.

# %% [markdown]
# * Emotion assigned to Antonnio, but this emotion **belongs to the authour** or Venetian People (which is implied, but not explicitly written)

# %% [markdown]
# #### **#3:** Emotion is Unassigned due to Lack of Entity Disambiguation in the absence of a Named Entity

# %%
dfp[dfp.index==12]
# Out:
# Person1  Antonio Bassanio Jew Portia Shylock again Shylock that--
# TimeStep
# 12                                                                 \
#
# Person1                                            Sentence
# TimeStep
# 12        He hates our Jewish nation; he lends out money...

# %%
print(dfp["Sentence"][12])
# Out:
# He hates our Jewish nation; he lends out money gratis; and among the merchants he rails at me and my well-earned bargains, which he calls interest.

# %% [markdown]
# * No emotion assigned to Antonio (**implied in "He"**) due to the absence of a Named Entity

# %% [markdown]
# #### **#4:** Misidentifiation as Named Entities

# %%
dfp.columns
# Out:
# Index(['Antonio', 'Bassanio', 'Jew', 'Portia', 'Shylock', 'again Shylock',
#        'that--', 'Sentence'],
#       dtype='object', name='Person1')

# %% [markdown]
# * 'again Shylock' is just the same as 'Shylock'
# * 'that--' is not a Named Entity
# * Single occurance of this error, can be fixed manually
