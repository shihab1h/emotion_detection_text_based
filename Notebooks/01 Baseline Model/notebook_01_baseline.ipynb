# %%
# IMPORTS
import pandas as pd
import numpy as np
import spacy
from transformers import RobertaTokenizerFast, RobertaForSequenceClassification, pipeline

# %% [markdown]
# ### **Process Corpus Text**

# %%
# IMPORT NOVEL TEXT
with open("MV_Abrv_Full.txt", "r", encoding="utf-8") as file:
    content = file.readlines()

# %%
# SEPARATE SENTENCES
content = [c.rstrip()+" " for c in content]
content = "".join(content)
content = content.split(". ")
content = [c+"." for c in content]

# %% [markdown]
# ### **Initialize SpaCy and BERT Models**

# %% [markdown]
# The SpaCy model is used in this notebook for Named Entity Recognition (NER)

# %%
# INITIATE English SpaCy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The BERT model is used for Emotion Detection (ED)
# * based on the entire sentence sentiment (later referred as "Sentence Emotion")
# * not on a deeper understanding of the meaning
# * 2 models are explored: AG and BS (abbreviated by their authors' names)

# %%
# Emotion Detector
tokenizer = RobertaTokenizerFast.from_pretrained("arpanghoshal/EmoRoBERTa")
model = RobertaForSequenceClassification.from_pretrained("arpanghoshal/EmoRoBERTa", from_tf=True)
emotion = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# Out:
# All TF 2.0 model weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
emotion2 = pipeline("text-classification", model='bhadresh-savani/distilbert-base-uncased-emotion', top_k=None)
# Out:
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %% [markdown]
# ### **Analysis**

# %% [markdown]
# #### **#1:** Identification of Characters and Sentence Emotions

# %% [markdown]
# Each sentence is a discrete timestep, where:
# * one character is identified at max, if any (no Entity Disambiguation)
# * an overall sentence emotion

# %%
# Initializing Dataframe
df = pd.DataFrame(columns=["Sentence", "Entities", "Persons", "SynDep", "Emotion_AG", "Emotion_BS"])
df["Sentence"] = content

# %%
# Populating Dataframe
for i in df.index:

    sentence_nlp = nlp(df["Sentence"][i])
    entities = sentence_nlp.ents
    entities_dict = {str(t): t.label_ for t in entities}
    indices_entities = [e.start for e in entities if e.label_=="PERSON"]

    df["Entities"][i] = entities_dict
    df["Persons"][i] = [e.lemma_ for e in entities if e.label_=="PERSON"] # Only keep Named Enities who are Persons
    df["SynDep"][i] = [sentence_nlp[ind+1].dep_ \
                       if sentence_nlp[ind].dep_=="compound" \
                        else sentence_nlp[ind].dep_ \
                            for ind in indices_entities ]  
    df["Emotion_AG"][i] = emotion(df["Sentence"][i])[0]['label'] # ED model 1
    df["Emotion_BS"][i] = emotion2(df["Sentence"][i])[0][0]['label'] # ED model 2

# %%
df.head(50)
# Out:
#                                              Sentence
# 0   Shylock, the Jew, lived at Venice: he was an u...  \
# 1   Shylock, being a hard-hearted man, exacted the...
# 2   Whenever Antonio met Shylock on the Rialto (or...
# 3    Antonio was the kindest man that lived, the b...
# 4   He was greatly beloved by all his fellow-citiz...
# 5   Whenever Bassanio wanted money, Antonio assist...
# 6    One day Bassanio came to Antonio, and told hi...
# 7    Antonio had no money by him at that time to l...
# 8    Antonio and Bassanio went together to Shylock...
# 9   On this, Shylock thought within himself: 'If I...
# 10  Cursed be my tribe if I forgive him!' Antonio ...
# 11  Well then, it now appears you need my help; an...
# 12  Has a dog money? Is it possible a cur should l...
# 13  If you will lend me this money, lend it not to...
# 14     I will forget the shames you have put upon me.
# 15  I will supply your wants, and take no interest...
# 16   'Content,' said Antonio: 'I will sign to this...
# 17   Shylock, hearing this debate, exclaimed: 'O, ...
# 18  I pray you tell me this, Bassanio: if he shoul...
# 19  I say, to buy his favour I offer this friendsh...
# 20   The rich heiress that Bassanio wished to marr...
# 21   Bassanio being so kindly supplied with money ...
# 22   Bassanio proving successful in his suit, Port...
# 23   Bassanio confessed to Portia that he had no f...
# 24  But yesterday, Bassanio, I was the lady of thi...
# 25   Bassanio was so overpowered with gratitude an...
# 26   Gratiano and Nerissa, Portia's waiting-maid, ...
# 27   'With all my heart, Gratiano,' said Bassanio,...
# 28   Gratiano then said that he loved the lady Por...
# 29             Portia asked Nerissa if this was true.
# 30  Nerissa replied: 'Madam, it is so, if you appr...
# 31  When Bassanio read Antonio's letter, Portia fe...
# 32   The day of payment being past, the cruel Jew ...
# 33  A day was appointed to try this shocking cause...
# 34   When Portia parted with her husband, she spok...
# 35   Portia had a relation who was a counsellor in...
# 36  When the messenger returned, he brought letter...
# 37   Portia dressed herself and her maid Nerissa i...
# 38  The cause was just going to be heard before th...
# 39  This the duke granted, much wondering at the y...
# 40                And now began this important trial.
# 41  Portia looked around her, and she knew the mer...
# 42  He was standing beside Antonio, in an agony of...
# 43   The importance of the arduous task Portia had...
# 44  Shylock only answered her by desiring to have ...
# 45   'Is he not able to pay the money?' asked Portia.
# 46  Bassanio then offered the Jew the payment of t...
# 47  But Portia gravely answered, that laws once es...
# 48  Shylock hearing Portia say that the law might ...
# 49  Then he said to Bassanio: 'Give me your hand, ...
#
#                                              Entities
# 0   {'Shylock': 'PERSON', 'Jew': 'NORP', 'Venice':...  \
# 1   {'Shylock': 'PERSON', 'Antonio': 'PERSON', 'Ve...
# 2   {'Antonio': 'PERSON', 'Shylock': 'PERSON', 'Je...
# 3   {'Antonio': 'PERSON', 'Roman': 'NORP', 'Italy'...
# 4          {'Bassanio': 'PERSON', 'Venetian': 'NORP'}
# 5   {'Bassanio': 'PERSON', 'Antonio': 'PERSON', 'o...
# 6   {'One day': 'DATE', 'Bassanio': 'GPE', 'Antoni...
# 7          {'Antonio': 'PERSON', 'Shylock': 'PERSON'}
# 8   {'Antonio': 'PERSON', 'Bassanio': 'GPE', 'Shyl...
# 9             {'Shylock': 'PERSON', 'Jewish': 'NORP'}
# 10  {'Antonio': 'PERSON', 'Shylock': 'PERSON', 'Je...
# 11                              {'Shylock': 'PERSON'}
# 12  {'three thousand ducats': 'QUANTITY', 'Fair': ...
# 13                              {'Shylock': 'PERSON'}
# 14                                                 {}
# 15  {'Antonio': 'PERSON', 'Shylock': 'PERSON', 'th...
# 16  {'Antonio': 'PERSON', 'Jew': 'NORP', 'Bassanio...
# 17  {'Shylock': 'PERSON', 'Abraham': 'PERSON', 'Ch...
# 18         {'Bassanio': 'PERSON', 'this day': 'DATE'}
# 19  {'Bassanio': 'GPE', 'Jew': 'PERSON', 'Antonio'...
# 20  {'Bassanio': 'PERSON', 'Venice': 'GPE', 'Belmo...
# 21  {'Antonio': 'PERSON', 'Belmont': 'GPE', 'Grati...
# 22                               {'Portia': 'PERSON'}
# 23  {'Portia': 'PERSON', 'a thousand': 'CARDINAL',...
# 24           {'yesterday': 'DATE', 'Bassanio': 'GPE'}
# 25                               {'Portia': 'PERSON'}
# 26  {'Portia': 'PERSON', 'Bassanio': 'PERSON', 'Gr...
# 27          {'Gratiano': 'ORG', 'Bassanio': 'PERSON'}
# 28  {'Gratiano': 'ORG', 'Portia': 'PERSON', 'Bassa...
# 29          {'Portia': 'PERSON', 'Nerissa': 'PERSON'}
# 30  {'Portia': 'PERSON', 'Bassanio': 'GPE', 'Grati...
# 31  {'Bassanio': 'PERSON', 'Antonio': 'PERSON', 'P...
# 32  {'The day': 'DATE', 'Jew': 'PERSON', 'Bassanio...
# 33            {'Venice': 'GPE', 'Bassanio': 'PERSON'}
# 34  {'Portia': 'PERSON', 'Antonio': 'GPE', 'Bassan...
# 35                               {'Portia': 'PERSON'}
# 36                                                 {}
# 37  {'Portia': 'PERSON', 'Venice': 'GPE', 'the ver...
# 38  {'Venice': 'GPE', 'senate': 'ORG', 'Portia': '...
# 39                                                 {}
# 40                                                 {}
# 41  {'Portia': 'PERSON', 'Jew': 'NORP', 'Bassanio'...
# 42                              {'Antonio': 'PERSON'}
# 43  {'Portia': 'PERSON', 'first': 'ORDINAL', 'Shyl...
# 44                                                 {}
# 45                               {'Portia': 'PERSON'}
# 46  {'Jew': 'NORP', 'three thousand ducats': 'QUAN...
# 47                               {'Portia': 'PERSON'}
# 48  {'Shylock': 'PERSON', 'Portia': 'PERSON', 'Jew...
# 49                                {'Bassanio': 'GPE'}
#
#                                               Persons
# 0                                           [Shylock]  \
# 1       [Shylock, Antonio, Shylock, Antonio, Antonio]
# 2                                  [Antonio, Shylock]
# 3                                           [Antonio]
# 4                                          [Bassanio]
# 5                                 [Bassanio, Antonio]
# 6                                  [Antonio, Antonio]
# 7                                  [Antonio, Shylock]
# 8                         [Antonio, Shylock, Antonio]
# 9                                           [Shylock]
# 10                [Antonio, Shylock, Signior Antonio]
# 11                                          [Shylock]
# 12                                          [Antonio]
# 13                                          [Shylock]
# 14                                                 []
# 15      [Antonio, Shylock, Antonio, Antonio, Shylock]
# 16              [Antonio, Bassanio, Antonio, Antonio]
# 17                                 [Shylock, Abraham]
# 18                                         [Bassanio]
# 19                                     [Antonio, Jew]
# 20                 [Bassanio, Portia, Portia, Brutus]
# 21                                          [Antonio]
# 22                                           [Portia]
# 23                                   [Portia, Portia]
# 24                                         [Bassanio]
# 25                                           [Portia]
# 26                         [Portia, Portia, Bassanio]
# 27                                         [Bassanio]
# 28                                           [Portia]
# 29                                  [Portia, Nerissa]
# 30                                  [Portia, Antonio]
# 31  [Bassanio, Antonio, Portia, Portia, Portia, An...
# 32                           [Jew, Bassanio, Antonio]
# 33                                         [Bassanio]
# 34                        [Portia, Antonio, Bassanio]
# 35                                           [Portia]
# 36                                                 []
# 37                                           [Portia]
# 38               [Portia, Antonio, Balthasar, Portia]
# 39                                                 []
# 40                                                 []
# 41                                 [Portia, Bassanio]
# 42                                          [Antonio]
# 43                [Portia, Shylock, Shylock, Shylock]
# 44                                                 []
# 45                                           [Portia]
# 46              [Shylock, Antonio, Bassanio, Antonio]
# 47                                           [Portia]
# 48  [shylock, Portia, Portia, Shylock, Antonio, Sh...
# 49                                                 []
#
#                                                SynDep   Emotion_AG Emotion_BS
# 0                                             [nsubj]      neutral        joy
# 1                   [nsubj, pobj, nsubj, dobj, appos]        anger      anger
# 2                                       [nsubj, dobj]      neutral      anger
# 3                                             [nsubj]   admiration      anger
# 4                                              [attr]         love        joy
# 5                                      [nsubj, nsubj]      neutral        joy
# 6                                        [pobj, dobj]      neutral    sadness
# 7                                       [nsubj, pobj]      neutral        joy
# 8                                [nsubj, pobj, nsubj]      neutral      anger
# 9                                             [nsubj]      neutral      anger
# 10                           [nsubj, npadvmod, nsubj]      neutral      anger
# 11                                             [dobj]      neutral       fear
# 12                                            [nsubj]      neutral      anger
# 13                                            [nsubj]      neutral       fear
# 14                                                 []  realization    sadness
# 15                  [dobj, nsubj, poss, nsubj, nsubj]      neutral   surprise
# 16                       [nsubj, nsubj, nsubj, nsubj]      neutral        joy
# 17                                     [nsubj, appos]      neutral       fear
# 18                                              [dep]      neutral        joy
# 19                                     [nsubj, nsubj]     approval   surprise
# 20                          [nsubj, attr, pobj, pobj]      neutral        joy
# 21                                            [appos]      neutral        joy
# 22                                            [appos]      neutral        joy
# 23                                      [pobj, nsubj]      neutral        joy
# 24                                         [npadvmod]      neutral        joy
# 25                                            [nsubj]    gratitude        joy
# 26                                [poss, nsubj, dobj]      neutral        joy
# 27                                            [nsubj]      neutral        joy
# 28                                             [poss]      neutral       love
# 29                                      [nsubj, dobj]      neutral        joy
# 30                                      [nsubj, pobj]          joy       fear
# 31  [nsubj, poss, nsubj, nsubj, dobj, pobj, nsubj,...         love        joy
# 32                               [nsubj, nsubj, poss]      neutral      anger
# 33                                            [nsubj]         fear      anger
# 34                                [nsubj, pobj, dobj]      neutral      anger
# 35                                            [nsubj]      neutral       love
# 36                                                 []      neutral        joy
# 37                                            [nsubj]      neutral      anger
# 38                         [nsubj, pobj, appos, oprd]      neutral        joy
# 39                                                 []     surprise        joy
# 40                                                 []      neutral        joy
# 41                                      [nsubj, dobj]      neutral      anger
# 42                                             [pobj]      neutral       fear
# 43                          [nsubj, pobj, conj, dobj]      neutral       love
# 44                                                 []       desire      anger
# 45                                             [dobj]      neutral      anger
# 46                         [nsubj, poss, nsubj, poss]       desire      anger
# 47                                            [nsubj]         fear        joy
# 48  [nsubj, dobj, nsubj, dobj, poss, pobj, ROOT, n...      neutral        joy
# 49                                                 []       caring    sadness

# %%
df["Person1"] = [p[0] if p else "" for p in df["Persons"]] # Assign emotion to 1st Named Entity identified (simplification by this baseline notebook model)

# %% [markdown]
# The lack of a "neutral" emotion label in the BS model results in an overfitting of non-neutral emotions when none exist

# %% [markdown]
# #### **2:** Emotional Timeline of Characters

# %%
dfp = df.reset_index().pivot(index=["index"], columns=["Person1"], values="Emotion_AG")
dfp1 = df.reset_index().pivot(index=["index"], columns=["Person1"], values="Emotion_BS")

# %%
#dfp = dfp.fillna(method="ffill", axis=0) # Forward fill the detected emotion of a character
dfp = dfp.fillna("") # Replace NaN with ""
dfp = dfp[dfp.columns.drop("")] # Drop non-character sentences
dfp.index.names = ["TimeStep"]

# %%
#dfp1 = dfp1.fillna(method="ffill", axis=0) # Forward fill the detected emotion of a character
dfp1 = dfp1.fillna("") # Replace NaN with ""
dfp1 = dfp1[dfp1.columns.drop("")] # Drop non-character sentences
dfp1.index.names = ["TimeStep"]

# %%
dfp["Sentence"] = df["Sentence"]
dfp.head()
# Out:
# Person1      Antonio Bassanio Daniel Jew Nerissa Portia  Shylock shylock
# TimeStep
# 0                                                        neutral          \
# 1                                                          anger
# 2            neutral
# 3         admiration
# 4                        love
#
# Person1                                            Sentence
# TimeStep
# 0         Shylock, the Jew, lived at Venice: he was an u...
# 1         Shylock, being a hard-hearted man, exacted the...
# 2         Whenever Antonio met Shylock on the Rialto (or...
# 3          Antonio was the kindest man that lived, the b...
# 4         He was greatly beloved by all his fellow-citiz...

# %%
dfp1["Sentence"] = df["Sentence"]
dfp1.head()
# Out:
# Person1  Antonio Bassanio Daniel Jew Nerissa Portia Shylock shylock
# TimeStep
# 0                                                       joy          \
# 1                                                     anger
# 2          anger
# 3          anger
# 4                     joy
#
# Person1                                            Sentence
# TimeStep
# 0         Shylock, the Jew, lived at Venice: he was an u...
# 1         Shylock, being a hard-hearted man, exacted the...
# 2         Whenever Antonio met Shylock on the Rialto (or...
# 3          Antonio was the kindest man that lived, the b...
# 4         He was greatly beloved by all his fellow-citiz...

# %%
dfp.to_csv("MV_emotional_timeline_AG.csv")
dfp1.to_csv("MV_emotional_timeline_BS.csv")

# %% [markdown]
# Potential Improvements:
# * Add logic to extract emotion form sentences without a proper noun name
# * Add logic to apply emotion to multiple persons if mentioned in same sentence
# * Add logic to extract who has which emotion (subject/object)

# %% [markdown]
# ### **Observations on Shortcomings of Initial Model**

# %% [markdown]
# #### **#1:** Long Sentences
# * are more likely to containt Multiple NERs
# * with Multiple Emotions
# * not captured by this initial model

# %%
dfp[dfp.index==1]
# Out:
# Person1  Antonio Bassanio Daniel Jew Nerissa Portia Shylock shylock
# TimeStep
# 1                                                     anger          \
#
# Person1                                            Sentence
# TimeStep
# 1         Shylock, being a hard-hearted man, exacted the...

# %%
print(dfp["Sentence"][1])
# Out:
# Shylock, being a hard-hearted man, exacted the payment of the money he lent with such severity that he was much disliked by all good men, and particularly by Antonio, a young merchant of Venice; and Shylock as much hated Antonio, because he used to lend money to people in distress, and would never take any interest for the money he lent; therefore there was great enmity between this covetous Jew and the generous merchant Antonio.

# %% [markdown]
# * Long sentence with many idea, perhaps **good to split at the semi-colon**
# * Shylock has **hatred, not anger** (limitation of chosen model)
# * Emotion **assigned only to one Person while multiple persons have emotions** (e.g., Antonio also "dislikes" (hatred) Shylock)
# * "all good men" also exhibit a dislike/hatred emotion, unidentified as they are not a Named Entity

# %% [markdown]
# #### **#2:** Emotion Assigned to Wrong Entity/Person

# %%
dfp[dfp.index==3]
# Out:
# Person1      Antonio Bassanio Daniel Jew Nerissa Portia Shylock shylock
# TimeStep
# 3         admiration                                                     \
#
# Person1                                            Sentence
# TimeStep
# 3          Antonio was the kindest man that lived, the b...

# %%
print(dfp["Sentence"][3])
# Out:
#  Antonio was the kindest man that lived, the best conditioned, and had the most unwearied spirit in doing courtesies; indeed, he was one in whom the ancient Roman honour more appeared than in any that drew breath in Italy.

# %% [markdown]
# * Emotion assigned to Antonnio, but this emotion **belongs to the authour** or Venetian People (which is implied, but not explicitly written)

# %% [markdown]
# #### **#3:** Emotion is Unassigned due to Lack of Entity Disambiguation in the absence of a Named Entity

# %%
dfp[dfp.index==9]
# Out:
# Person1  Antonio Bassanio Daniel Jew Nerissa Portia  Shylock shylock
# TimeStep
# 9                                                    neutral          \
#
# Person1                                            Sentence
# TimeStep
# 9         On this, Shylock thought within himself: 'If I...

# %%
print(dfp["Sentence"][9])
# Out:
# On this, Shylock thought within himself: 'If I can once catch him on the hip, I will feed fat the ancient grudge I bear him; he hates our Jewish nation; he lends out money gratis, and among merchants he rails at me and my well-earned bargains, which he calls interest.

# %% [markdown]
# * No emotion (hated) assigned to Antonio (**implied in "He"**) due to the absence of a Named Entity

# %% [markdown]
# #### **#4:** Misidentifiation as Named Entities

# %%
dfp.columns
# Out:
# Index(['Antonio', 'Bassanio', 'Daniel', 'Jew', 'Nerissa', 'Portia', 'Shylock',
#        'shylock', 'Sentence'],
#       dtype='object', name='Person1')

# %% [markdown]
# * 'again shylock' is just the same as 'Shylock'
# * Single occurance of this error, can be fixed manually
